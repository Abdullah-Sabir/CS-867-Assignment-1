# %%
run assign-1.py

# %%
displayChannel() # Task 2.1

# %%
rgbExclusion('g')# the argument is a string value for the exclusion channel i.e ('r','g','b') Task 2.2

# %%
displayHist() #Task 2.3

# %%
  
    
convOp('04.jpg','b')# first argument image path
                    #second argument blur('b')/ Sharp('s')  
                   # Both arguments string values
                  #Task 2.4

# %%
convBox('05.jpg',(np.array([[-1, -1, -1], [-1, -8, -1], [-1, -1, -1]])/9.0)) #Task 2.5.1 Box Filter

# %%
gaussianFil('04.jpg') #Task 2.5.2 Apply Gaussian filter to the image, with varying sigma values.

# %%
noise('05.jpg') #Task 2.5.3 Add Gausian Noise and Salt and Pepper Noise

# %%
gaussMedFil('05.jpg') #Task 2.5.4 Apply Gaussian Filter and Median Filters.

# %%
meshPlotGaussian() #Task 2.5.5

# %%
sobelOp('01.jpg') #Task 2.6.1

# %%
Laplacian('02.jpg') # Task 2.6.2

# %%
canneyEdge('03.jpg') # Task 2.6.3

# %%
canneyVideo() #Task 2.7 it will convert your webcam feed 
              #Press enter to Exit out
